# %%
import numpy as np
import pandas as pd
from fitter import Fitter, get_common_distributions, get_distributions

data = pd.read_csv('/Users/benmazin/Code Dev/RP 4/netlogo results/results.csv')

# Fit the data to a distribution
f = Fitter(data['ChemoPercentInfect'].dropna().values, distributions=get_common_distributions())

f.fit()
f.summary()


print(f.get_best(method='sumsquare_error'))
# Out:
# 2024-04-02 12:30:56.515 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=1.46172)
# 2024-04-02 12:30:56.516 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=1.148858)
# 2024-04-02 12:30:56.613 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=1.362613)
# 2024-04-02 12:30:56.834 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=1.336543)
# 2024-04-02 12:30:56.859 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=1.291993)
# 2024-04-02 12:30:57.516 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=1.174556)
# 2024-04-02 12:30:57.599 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=1.14886)
# 2024-04-02 12:31:01.816 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=1.153296)
# 2024-04-02 12:31:02.421 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=1.153282)
# 2024-04-02 12:31:07.201 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=1.855627)
# {'norm': {'loc': 92.852298, 'scale': 3.009392981848001}}
