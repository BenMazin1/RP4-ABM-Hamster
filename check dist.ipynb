# %%
import numpy as np
import pandas as pd
from fitter import Fitter, get_common_distributions, get_distributions

data = pd.read_csv('/Users/benmazin/Code Dev/RP 4/netlogo results/results.csv')

# Fit the data to a distribution
f = Fitter(data['ChemoPercentInfect'].dropna().values, distributions='norm')

f.fit()
f.summary()


print(f.get_best(method='sumsquare_error'))
# Out:
# 2024-03-30 17:57:59.572 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=1.148858)
# {'norm': {'loc': 92.852298, 'scale': 3.009392981848001}}
